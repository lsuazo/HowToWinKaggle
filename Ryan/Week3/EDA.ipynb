# %%
# !ls
# Out:
# Untitled.ipynb

# %%
! ls ..
# Out:
# FinalProject Week1        Week2        Week3

# %%
! ls ../FinalProject

# %%
! ls ../FinalProject/

# %%
! ls ../../
# Out:
# FinalProject   Notes          Ryan
# FurtherReading README.md      minutes.txt

# %%
! ls ../../FinalProject/
# Out:
# 20200726_ExploratoryWork.ipynb          TODO.txt
# 20200727_project_to_item_category.ipynb cat_names.doc
# 20200728_rolling_fit_and_test.ipynb     cat_names.txt
# 20200731_previous_month_pred.ipynb      cat_names_english.docx
# 20200803_formalize_cross_val.ipynb      cat_names_english.txt
# 20200804_feature_engineering.ipynb      sample_submission.csv
# Notes.txt                               submissions
# Programming_assignment_week_3.ipynb     test_utilities.py
# SubmissionScores.txt                    utilities.py

# %%
! ls ../../FinalProject/submissions/
# Out:
# base_pred.csv                   jointRF_v0.csv
# constant_0.csv                  jointRF_v1_noClip.csv
# constant_0p25.csv               oct2015_values.csv
# constant_0p4.csv                oct2015_values_clipped.csv
# constant_0p6.csv                only_novembers.csv
# individual_rf_fit_months_24.csv

# %%
! ls ../
# Out:
# FinalProject Week1        Week2        Week3

# %%
! ls ../Week1/
# Out:
# EDA1.ipynb                         Week1 Recap of ML algorithms.ipynb
# Week 1 pandas Practice.ipynb

# %%
! ls ../Week2/
# Out:
# Springleaf_data
# Week 2 Spectral Biclustering.ipynb
# Week 2 Springleaf EDA.ipynb
# Week 2 Validation.ipynb
# Week 2 Working with anonymized data.ipynb

# %%
! cat ../../FinalProject/20200726_ExploratoryWork.ipynb
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 1,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import os\n",
#     "\n",
#     "import pandas as pd\n",
#     "import numpy as np\n",
#     "import seaborn as sns\n",
#     "import matplotlib.pyplot as plt\n",
#     "\n",
#     "%matplotlib inline"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 2,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "def load_and_preprocess(parse_date = True):\n",
#     "    data_fol = 'data'\n",
#     "    sales = pd.read_csv(os.path.join(data_fol, 'sales_train.csv'))\n",
#     "    if parse_date:\n",
#     "        date_col = pd.to_datetime(sales.date, format='%d.%m.%Y')\n",
#     "        sales.date = date_col\n",
#     "        sales['Month'] = sales.date.dt.to_period('M')\n",
#     "    return sales"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "metadata": {},
#    "outputs": [],
# ...

# %%
# !ls
# Out:
# Untitled.ipynb

# %%
# !ls ../
# Out:
# FinalProject Week1        Week2        Week3

# %%
# !ls ../FinalProject/
# Out:
# competitive-data-science-predict-future-sales.zip
